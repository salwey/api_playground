# %%
import json
import requests
from random import randint
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# ## Doggy Facts!

# %%
url = "https://dog-facts-api.herokuapp.com/api/v1/resources/dogs/all"
response = requests.get(url)
results = response.json()
doggy_data = pd.DataFrame(results)

# %%
doggy_data['fact'][randint(0,len(doggy_data)-1)]
# Out:
# 'About one-third of a dog’s brain is dedicated to smell.'

# %% [markdown]
# ## D & D

# %%
def flatten(data, col_list, include_original_name=False):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        if include_original_name:
            flattened.columns = [column + '_' + colname for colname in columns]
        else:
            flattened.columns = [colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
url = "https://api.open5e.com/monsters/"
response = requests.get(url)
response = response.json()

# %%
dd_data = pd.DataFrame(response)
dd_data = dd_data[['results']]
dd_data = flatten(dd_data, ['results'])
dd_data
# Out:
#                                     slug  \
# 0                                  aatxe
# 1                                aboleth
# 2                       aboleth-nihilith
# 3                      abominable-beauty
# 4                       accursed-defiler
# 5                               acid-ant
# 6                                acolyte
# 7                     adult-black-dragon
# 8                      adult-blue-dragon
# 9                     adult-brass-dragon
# 10                   adult-bronze-dragon
# 11                     adult-cave-dragon
# 12                   adult-copper-dragon
# 13                    adult-flame-dragon
# 14                     adult-gold-dragon
# 15                    adult-green-dragon
# 16                    adult-light-dragon
# 17                  adult-mithral-dragon
# 18                      adult-red-dragon
# 19                       adult-rime-worm
# 20                      adult-sea-dragon
# 21                   adult-silver-dragon
# ...

# %%
dd_data['actions'][0][1]
# Out:
# {'desc': "The aatxe lowers its horns and paws at the ground with its hooves. Each creature within 30 feet of the aatxe must succeed on a DC 15 Wisdom saving throw or be frightened for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success. If a creature's saving throw is successful or the effect ends for it, the creature is immune to the aatxe's Paw the Earth for the next 24 hours.",
#  'name': 'Paw the Earth'}

# %% [markdown]
# ## Random Facts (Useless but true facts)

# %%
url = "https://uselessfacts.jsph.pl/random.json?language=en"
response = requests.get(url)
results = response.json()
results["text"]
# Out:
# 'A spider has transparent blood.'
